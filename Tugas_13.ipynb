# %% [markdown]
# <a href="https://colab.research.google.com/github/YogaMarta/Pemrograman_Python/blob/main/Tugas_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Yoga Marta Hermawan |
# 1101194119 |
# TT-43-G1 |

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f=700 #MHz
f2=900 #MHz
f3=1800 #MHz
loc1='urban'
loc2='suburban'
loc3='open'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)
y=d**2
y2=d**3
y3=d**4

# %%
print(d)
# Out:
# [533 563 378 675 544 686 589 420 367 303 424 660 519 381 379 326 416 293
#  465 470 691 597 575 630 490 480 651 515 437 699 237 425 603 390 497 535
#  278 314 248 393 381 693 286 381 507 489 655 473 230 444 649 363 699 511
#  538 412 396 520 348 450 507 566 468 432 386 563 668 627 336 228 496 402
#  259 607 439 654 391 549 444 555 399 340 332 295 586 269 597 222 425 210
#  678 594 476 412 275 644 528 590 317 535 590 339 431 551 325 680 629 456
#  457 364 639 214 268 423 449 694 435 480 537 615 613 400 534 472 338 337
#  444 288 303 643 275 474 372 553 441 537 590 347 548 456 362 530 685 253
#  687 457 443 354 562 358 651 473 435 532 487 303 667 692 517 664 414 374
#  265 354 517 301 244 403 363 663 214 376 206 553 536 297 519 389 480 494
#  418 272 354 287 419 643 275 652 299 329 220 257 214 571 429 220 496 371
#  605 640]

# %%
LpUrban=cos(f3,loc1,tower,user,d)
LpSuburban=cos(f3,loc2,tower,user,d)
LpOpen=cos(f3,loc3,tower,user,d)

# %%
print(LpUrban)
print(LpSuburban)
print(LpOpen)
# Out:
# [183.44807925 184.21941631 178.60766448 186.77512553 183.73583041
#  187.00282867 184.85536142 180.09179773 178.19166482 175.4923326
#  180.22531757 186.45856755 183.07313824 178.71901871 178.64488045
#  176.5229462  179.95700017 175.0195957  181.52553294 181.67618932
#  187.10512569 185.04539786 184.51650088 185.80327556 182.26320082
#  181.97275265 186.26516079 182.96415327 180.65071828 187.26727123
#  172.03172909 180.25850071 185.18626141 179.04789523 182.46300896
#  183.50083675 174.27934286 175.99465037 172.67080204 179.15583628
#  178.71901871 187.14583739 174.67897923 178.71901871 182.74362058
#  182.23442403 186.35144736 181.76581574 171.60941197 180.87456785
#  186.22181849 178.03729354 187.26727123 182.8543185  183.57960436
#  179.8209002  179.26295647 183.10025324 177.44284933 181.06364771
#  182.74362058 184.29427692 181.61611999 180.48861939 178.902675
#  184.21941631 186.62828331 185.73603802 176.94854466 171.48638728
# ...

# %%
d_sort=d[np.argsort(d)]
Urban_sort=LpUrban[np.argsort(d)]
Suburban_sort=LpSuburban[np.argsort(d)]
Open_sort=LpOpen[np.argsort(d)]

# %%
plt.figure()
plt.title('Frekuensi 1800 MHz')
plt.plot(d_sort, Urban_sort, label='Urban')
plt.plot(d_sort, Suburban_sort, label='Suburban')
plt.plot(d_sort, Open_sort, label='Open')
plt.legend()
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %%
Lpf=cos(f,loc1,tower,user,d+50)
Lpf2=cos(f2,loc2,tower,user,d+50)
Lpf3=cos(f3,loc3,tower,user,d+50)

# %%
print(Lpf)
print(Lpf2)
print(Lpf3)
# Out:
# [172.07207498 172.77889068 167.71852619 175.14265598 172.3353768
#  175.35477308 173.3640262  169.03713183 167.35176319 165.00474014
#  169.15650744 174.84815945 171.72968429 167.81691707 167.75139957
#  165.89387876 168.9167359  164.59993534 170.32509577 170.46119575
#  175.45014404 173.53928492 173.05197653 174.24002598 170.99281497
#  170.72951314 174.66846015 171.63031007 169.53763597 175.60140711
#  162.08908841 169.18619393 173.66931265 168.10803223 171.17424096
#  172.12031556 163.97004333 165.43698776 162.61888971 168.20374882
#  167.81691707 175.48811236 164.30948716 167.81691707 171.4294334
#  170.96670516 174.74860966 170.54222897 161.74126241 169.73866622
#  174.62821373 167.21599117 175.60140711 171.53022981 172.19236809
#  168.79530207 168.2988194  171.75441869 166.69486254 169.90872346
#  171.4294334  172.84766008 170.40691345 169.39226587 167.97938989
#  172.77889068 175.0059901  174.17774333 166.26361751 161.64028536
# ...

# %%
d_sort=d[np.argsort(d)]
f_sort=Lpf[np.argsort(d)]
f2_sort=Lpf2[np.argsort(d)]
f3_sort=Lpf3[np.argsort(d)]

# %%
plt.figure()
plt.title('Model Urban')
plt.plot(d_sort, f_sort, label='700 MHz')
plt.plot(d_sort, f2_sort, label='900 MHz')
plt.plot(d_sort, f3_sort, label='1800 MHz')
plt.legend()
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
